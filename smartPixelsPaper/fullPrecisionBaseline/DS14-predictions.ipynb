# %%
import pandas as pd
import numpy as np
df1 = pd.read_csv('predictionsOnDS14.csv')
df1
# Out:
#          0
# 0        2
# 1        2
# 2        1
# 3        1
# 4        0
# ...     ..
# 3597872  0
# 3597873  0
# 3597874  0
# 3597875  0
# 3597876  0
#
# [3597877 rows x 1 columns]

# %%
df1.columns=['predict']
df1
# Out:
#          predict
# 0              2
# 1              2
# 2              1
# 3              1
# 4              0
# ...          ...
# 3597872        0
# 3597873        0
# 3597874        0
# 3597875        0
# 3597876        0
#
# [3597877 rows x 1 columns]

# %%
LowPT = df1[ (df1['predict'] ==1) |(df1['predict'] ==2) ]
LowPT
# Out:
#          predict
# 0              2
# 1              2
# 2              1
# 3              1
# 6              1
# ...          ...
# 3597854        2
# 3597858        1
# 3597861        2
# 3597866        2
# 3597871        1
#
# [1328713 rows x 1 columns]

# %%
132871/3597877
# Out:
# 0.036930389782641265
